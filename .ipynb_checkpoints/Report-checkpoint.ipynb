# %%
#import the necessary fucntion 
from cov_functions_AI import simulator
from parameters_cov_AI import params, parameter_csv, example_population_frame,example_population

# %%
parameter_csv
# Out:
#                      Name  Value  Unit             Type  \
# 0              No control    1.0   NaN          Control
# 1          Control name 1    0.9   NaN          Control
# 2          Control name 2    0.8   NaN          Control
# 3          Control name 3    0.5   NaN          Control
# 4                     NaN    NaN   NaN              NaN
# 5                      R0    4.0   NaN  Model Parameter
# 6       infectious_period    2.0  Days  Model Parameter
# 7   non_infectious_period    5.0  Days  Model Parameter
# 8             hosp_period    8.0  Days  Model Parameter
# 9            death_period    2.0  Days  Model Parameter
# 10  death_period_with_ICU    8.0  Days  Model Parameter
# 11             death_prob    1.0   NaN  Model Parameter
# 12    death_prob_with_ICU    0.5   NaN  Model Parameter
# 13    number_compartments    7.0   NaN  Model Parameter
#
#                   Explanation                     Assumptions
# ...

# %%
example_population
# Out:
# 20000.0
